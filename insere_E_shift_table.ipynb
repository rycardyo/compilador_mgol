# %%
import pandas as pd
_f = pd.read_csv('sintatico/Shift-Reduce.csv')
_f.head(5)
# Out:
#   inicio varinicio varfim escreva  leia    se entao fimse  fim inteiro  ...  \
# 0    S-2       NaN    NaN     NaN   NaN   NaN   NaN   NaN  NaN     NaN  ...
# 1    NaN       NaN    NaN     NaN   NaN   NaN   NaN   NaN  NaN     NaN  ...
# 2    NaN       S-4    NaN     NaN   NaN   NaN   NaN   NaN  NaN     NaN  ...
# 3    NaN       NaN    NaN    S-11  S-10  S-14   NaN   NaN  S-9     NaN  ...
# 4    NaN       NaN   S-17     NaN   NaN   NaN   NaN   NaN  NaN    S-19  ...
#
#    LIT    ID       $  OPR  ATR  OPA AB_P FC_P PT_V  VIR
# 0  NaN   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN   NaN  A-P'-P  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  S-12     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 23 columns]

# %%
_f.fillna('E-000',inplace=True)
_f.to_csv('sintatico/Shift-Reduce_2.csv',index=False, index_label=False)

# %%
_f
# Out:
#    inicio varinicio varfim                         escreva  \
# 0     S-2     E-000  E-000                           E-000
# 1   E-000     E-000  E-000                           E-000
# 2   E-000       S-4  E-000                           E-000
# 3   E-000     E-000  E-000                            S-11
# 4   E-000     E-000   S-17                           E-000
# ..    ...       ...    ...                             ...
# 57  E-000     E-000  E-000                           E-000
# 58  E-000     E-000  E-000                           E-000
# 59  E-000     E-000  E-000                           E-000
# 60  E-000     E-000  E-000  R-CAB-se AB_P EXP_R FC_P entao
# 61  E-000     E-000  E-000                           E-000
#
#                               leia                              se  entao  \
# 0                            E-000                           E-000  E-000
# 1                            E-000                           E-000  E-000
# ...

# %%
_f.to_excel('./shiff_reduce.xlsx')
